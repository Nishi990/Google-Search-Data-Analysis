# %%
pip install pandas pytrends matplotlib seaborn plotly
# Out:
# ...
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from pytrends.request import TrendReq

# %% [markdown]
# # setup pytrend libraray and keyword define

# %%
pytrends = TrendReq(hl ="en-US", tz = 360)
keyword = "Java"

# %% [markdown]
# # Data Request

# %%
pytrends.build_payload([keyword], cat = 0, timeframe = 'today 12-m', geo = '', gprop = '')

# %% [markdown]
# # Country Wise Interest

# %%
region_data = pytrends.interest_by_region()
region_data = region_data.sort_values(by=keyword, ascending = False).head(15)

# %%
plt.figure(figsize= (10,6))
sns.barplot(x= region_data[keyword], y = region_data.index, palette = 'Blues_d')
plt.title(f"Top Countries searching for '{keyword}'")
plt.xlabel("Interest")
plt.ylabel("Country")
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_16524\1281057707.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x= region_data[keyword], y = region_data.index, palette = 'Blues_d')

# %% [markdown]
# # World Map

# %%
import plotly.express as px

region_data = region_data.reset_index(drop=True)

fig = px.choropleth(
    region_data,
    locations='index',  
    locationmode="country names",
    color=keyword,
    title=f"Search Interest for '{keyword}' by Country",
    color_continuous_scale="algae"
)
fig.show()

# %% [markdown]
# # Time Wise Interest

# %%
time_df = pytrends.interest_over_time()
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\pytrends\request.py:260: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`

# %%
plt.figure(figsize=(12,6))
plt.plot(time_df.index, time_df[keyword], marker="o", color="red")
plt.title(f"Search Interest Over Time For '{keyword}' ")
plt.xlabel("Date")
plt.ylabel("Interest")
plt.grid(True)
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Multiple Words Comparision Using Line Plot

# %%
kw_list= ["Cloud Computing", "Artificial Intelligence", "Machine Learning", "Data Science", "Data Analyst"]
pytrends.build_payload(kw_list, cat= 0, timeframe = 'today 12-m', geo='', gprop='')

# %%
compare_df = pytrends.interest_over_time()
plt.figure(figsize=(12,6))
for kw in kw_list:
    plt.plot(compare_df.index, compare_df[kw], label=kw)
plt.title("Keyword Comparision Over Time")
plt.xlabel("Date")
plt.ylabel("Search Interest")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\pytrends\request.py:260: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
